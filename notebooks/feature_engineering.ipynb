# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv("../data/cleaned_weather.csv")
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated', 'temperature_celsius', 'condition_text', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'precip_mm', 'humidity',
#        'cloud', 'feels_like_celsius', 'visibility_km', 'uv_index', 'gust_kph',
#        'air_quality_Carbon_Monoxide', 'air_quality_Ozone',
#        'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide',
#        'air_quality_PM2.5', 'air_quality_PM10'],
#       dtype='object')

# %% [markdown]
# ## Create Lag Features (Past Time Steps as Input)
#
# - LSTM and Transformers need past data to learn temporal dependencies.
# - Adding lag features allows the model to learn from past weather conditions.

# %%
lag_days = 7
for i in range(1, lag_days + 1):
    df[f'temperature_lag_{i}'] = df['temperature_celsius'].shift(i)
    df[f'humidity_lag_{i}'] = df['humidity'].shift(i)

# %%
df.head(10)
# Out:
#                country     location_name  latitude  longitude  \
# 0          Afghanistan             Kabul     34.52      69.18
# 1              Albania            Tirana     41.33      19.82
# 2              Algeria           Algiers     36.76       3.05
# 3              Andorra  Andorra La Vella     42.50       1.52
# 4               Angola            Luanda     -8.84      13.23
# 5  Antigua and Barbuda      Saint John's     17.12     -61.85
# 6            Argentina      Buenos Aires    -34.59     -58.67
# 7              Armenia           Yerevan     40.18      44.51
# 8            Australia          Canberra    -35.28     149.22
# 9              Austria            Vienna     48.20      16.37
#
#                          timezone      last_updated  temperature_celsius  \
# 0                      Asia/Kabul  2024-05-16 13:15                 26.6
# 1                   Europe/Tirane  2024-05-16 10:45                 19.0
# 2                  Africa/Algiers  2024-05-16 09:45                 23.0
# 3                  Europe/Andorra  2024-05-16 10:45                  6.3
# 4                   Africa/Luanda  2024-05-16 09:45                 26.0
# 5                 America/Antigua  2024-05-16 04:45                 26.0
# 6  America/Argentina/Buenos_Aires  2024-05-16 05:45                  8.0
# 7                    Asia/Yerevan  2024-05-16 12:45                 19.0
# 8                Australia/Sydney  2024-05-16 18:45                  9.0
# 9                   Europe/Vienna  2024-05-16 10:45                 16.0
#
#   condition_text  wind_kph  wind_degree  ... temperature_lag_3  \
# 0  Partly Cloudy      13.3          338  ...               NaN
# 1  Partly cloudy      11.2          320  ...               NaN
# 2          Sunny      15.1          280  ...               NaN
# 3  Light drizzle      11.9          215  ...              26.6
# 4  Partly cloudy      13.0          150  ...              19.0
# 5  Partly cloudy       9.0           90  ...              23.0
# 6          Clear       3.6           10  ...               6.3
# 7  Partly cloudy       6.8          140  ...              26.0
# 8          Clear       4.0          100  ...              26.0
# 9  Partly cloudy      20.2          110  ...               8.0
#
#    humidity_lag_3  temperature_lag_4  humidity_lag_4  temperature_lag_5  \
# 0             NaN                NaN             NaN                NaN
# 1             NaN                NaN             NaN                NaN
# 2             NaN                NaN             NaN                NaN
# 3            24.0                NaN             NaN                NaN
# 4            94.0               26.6            24.0                NaN
# 5            29.0               19.0            94.0               26.6
# 6            61.0               23.0            29.0               19.0
# 7            89.0                6.3            61.0               23.0
# 8            84.0               26.0            89.0                6.3
# 9            93.0               26.0            84.0               26.0
#
#    humidity_lag_5  temperature_lag_6  humidity_lag_6  temperature_lag_7  \
# 0             NaN                NaN             NaN                NaN
# 1             NaN                NaN             NaN                NaN
# 2             NaN                NaN             NaN                NaN
# 3             NaN                NaN             NaN                NaN
# 4             NaN                NaN             NaN                NaN
# 5            24.0                NaN             NaN                NaN
# 6            94.0               26.6            24.0                NaN
# 7            29.0               19.0            94.0               26.6
# 8            61.0               23.0            29.0               19.0
# 9            89.0                6.3            61.0               23.0
#
#    humidity_lag_7
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7            24.0
# 8            94.0
# 9            29.0
#
# [10 rows x 39 columns]

# %% [markdown]
# ##  Rolling Window Statistics (Smoothing & Trend Capturing)
# - Rolling mean captures trends, while rolling standard deviation detects fluctuations and anomalies over a time window.

# %%
df['temperature_rolling_mean_3d'] = df['temperature_celsius'].rolling(window=3).mean()
df['temperature_rolling_std_7d'] = df['temperature_celsius'].rolling(window=7).std()
df['humidity_rolling_mean_3d'] = df['humidity'].rolling(window=3).mean()
df['humidity_rolling_std_7d'] = df['humidity'].rolling(window=7).std()

# %%
df
# Out:
#            country     location_name  latitude  longitude         timezone  \
# 0      Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1          Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2          Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3          Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4           Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...            ...               ...       ...        ...              ...
# 56901    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 56902      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 56903        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 56904       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 56905     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
#            last_updated  temperature_celsius      condition_text  wind_kph  \
# 0      2024-05-16 13:15                 26.6       Partly Cloudy      13.3
# 1      2024-05-16 10:45                 19.0       Partly cloudy      11.2
# 2      2024-05-16 09:45                 23.0               Sunny      15.1
# 3      2024-05-16 10:45                  6.3       Light drizzle      11.9
# 4      2024-05-16 09:45                 26.0       Partly cloudy      13.0
# ...                 ...                  ...                 ...       ...
# 56901  2025-03-05 06:00                 24.4               Clear       3.6
# 56902  2025-03-05 17:00                 26.4       Partly cloudy       8.6
# 56903  2025-03-05 13:00                 24.6  Patchy rain nearby      18.4
# 56904  2025-03-05 12:00                 23.4  Patchy rain nearby      14.8
# 56905  2025-03-05 12:00                 25.4  Patchy rain nearby       7.6
#
#        wind_degree  ... temperature_lag_5  humidity_lag_5  temperature_lag_6  \
# 0              338  ...               NaN             NaN                NaN
# 1              320  ...               NaN             NaN                NaN
# 2              280  ...               NaN             NaN                NaN
# 3              215  ...               NaN             NaN                NaN
# 4              150  ...               NaN             NaN                NaN
# ...            ...  ...               ...             ...                ...
# 56901           55  ...               7.1            81.0               30.4
# 56902           70  ...               4.6            95.0                7.1
# 56903          243  ...              23.3           100.0                4.6
# 56904           92  ...              12.1            30.0               23.3
# 56905           71  ...              26.2            89.0               12.1
#
#        humidity_lag_6  temperature_lag_7  humidity_lag_7  \
# 0                 NaN                NaN             NaN
# 1                 NaN                NaN             NaN
# 2                 NaN                NaN             NaN
# 3                 NaN                NaN             NaN
# 4                 NaN                NaN             NaN
# ...               ...                ...             ...
# 56901            24.0                7.3            64.0
# 56902            81.0               30.4            24.0
# 56903            95.0                7.1            81.0
# 56904           100.0                4.6            95.0
# 56905            30.0               23.3           100.0
#
#        temperature_rolling_mean_3d  temperature_rolling_std_7d  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                        22.866667                         NaN
# 3                        16.100000                         NaN
# 4                        18.433333                         NaN
# ...                            ...                         ...
# 56901                    20.900000                   10.186592
# 56902                    25.666667                    9.482565
# 56903                    25.133333                    8.465757
# 56904                    24.800000                    4.921527
# 56905                    24.466667                    5.012128
#
#        humidity_rolling_mean_3d  humidity_rolling_std_7d
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                     49.000000                      NaN
# 3                     61.333333                      NaN
# 4                     59.666667                      NaN
# ...                         ...                      ...
# 56901                 62.666667                30.885349
# 56902                 79.000000                23.408383
# 56903                 57.333333                30.772591
# 56904                 58.000000                28.717010
# 56905                 49.333333                24.648964
#
# [56906 rows x 43 columns]

# %% [markdown]
# ## Seasonal Features (Month, Day, Hour Cyclic Encoding)
# - Weather follows seasonal trends (monthly, weekly, daily).
# - Using plain integers makes the model think that January (1) and December (12) are far apart, when in reality, they are close in seasonal cycles.
#
# For example:
#
# 1. If we train a model with month = 12 (December) and month = 1 (January), it will assume these values are very different.
# 2. But in reality, December and January are neighbors in the annual weather cycle.

# %%
df['last_updated'] = pd.to_datetime(df['last_updated'])
df.set_index('last_updated', inplace=True)

df['month'] = df.index.month
df['day_of_week'] = df.index.dayofweek
df['hour_of_day'] = df.index.hour

# sine & cosine formulas for cyclic encoding
df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)
df['hour_sin'] = np.sin(2 * np.pi * df['hour_of_day'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour_of_day'] / 24)

# %%
df.head()
# Out:
#                          country     location_name  latitude  longitude  \
# last_updated
# 2024-05-16 13:15:00  Afghanistan             Kabul     34.52      69.18
# 2024-05-16 10:45:00      Albania            Tirana     41.33      19.82
# 2024-05-16 09:45:00      Algeria           Algiers     36.76       3.05
# 2024-05-16 10:45:00      Andorra  Andorra La Vella     42.50       1.52
# 2024-05-16 09:45:00       Angola            Luanda     -8.84      13.23
#
#                            timezone  temperature_celsius condition_text  \
# last_updated
# 2024-05-16 13:15:00      Asia/Kabul                 26.6  Partly Cloudy
# 2024-05-16 10:45:00   Europe/Tirane                 19.0  Partly cloudy
# 2024-05-16 09:45:00  Africa/Algiers                 23.0          Sunny
# 2024-05-16 10:45:00  Europe/Andorra                  6.3  Light drizzle
# 2024-05-16 09:45:00   Africa/Luanda                 26.0  Partly cloudy
#
#                      wind_kph  wind_degree wind_direction  ...  \
# last_updated                                               ...
# 2024-05-16 13:15:00      13.3          338            NNW  ...
# 2024-05-16 10:45:00      11.2          320             NW  ...
# 2024-05-16 09:45:00      15.1          280              W  ...
# 2024-05-16 10:45:00      11.9          215             SW  ...
# 2024-05-16 09:45:00      13.0          150            SSE  ...
#
#                      temperature_rolling_std_7d  humidity_rolling_mean_3d  \
# last_updated
# 2024-05-16 13:15:00                         NaN                       NaN
# 2024-05-16 10:45:00                         NaN                       NaN
# 2024-05-16 09:45:00                         NaN                 49.000000
# 2024-05-16 10:45:00                         NaN                 61.333333
# 2024-05-16 09:45:00                         NaN                 59.666667
#
#                      humidity_rolling_std_7d  month  day_of_week  hour_of_day  \
# last_updated
# 2024-05-16 13:15:00                      NaN      5            3           13
# 2024-05-16 10:45:00                      NaN      5            3           10
# 2024-05-16 09:45:00                      NaN      5            3            9
# 2024-05-16 10:45:00                      NaN      5            3           10
# 2024-05-16 09:45:00                      NaN      5            3            9
#
#                      month_sin  month_cos  hour_sin  hour_cos
# last_updated
# 2024-05-16 13:15:00        0.5  -0.866025 -0.258819 -0.965926
# 2024-05-16 10:45:00        0.5  -0.866025  0.500000 -0.866025
# 2024-05-16 09:45:00        0.5  -0.866025  0.707107 -0.707107
# 2024-05-16 10:45:00        0.5  -0.866025  0.500000 -0.866025
# 2024-05-16 09:45:00        0.5  -0.866025  0.707107 -0.707107
#
# [5 rows x 49 columns]

# %%
df.isna().sum().sum()
# Out:
# np.int64(72)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Weather-Specific Features (Custom Domain Features)
# - Humidity × Temperature captures heat
# - Wind Speed categorizes wind intensity
# - Dew Point measures moisture in the air

# %%
df['humidity_temperature_interaction'] = df['humidity'] * df['temperature_celsius']
df['wind_category'] = pd.cut(df['wind_kph'], bins=[0, 10, 20, 30], labels=['low', 'moderate', 'high'])
df['dew_point'] = df['temperature_celsius'] - ((100 - df['humidity']) / 5)

# %% [markdown]
# ##  Outlier Handling using IQR (Interquartile Range)
# Extreme outliers distort forecasting models, so we remove them using IQR.

# %%
Q1 = df['temperature_celsius'].quantile(0.25)
Q3 = df['temperature_celsius'].quantile(0.75)
IQR = Q3 - Q1
outlier_condition = (df['temperature_celsius'] < (Q1 - 1.5 * IQR)) | (df['temperature_celsius'] > (Q3 + 1.5 * IQR))
df = df[~outlier_condition]

# %% [markdown]
# ## Smoothing using Exponential Moving Average (EMA)
#
# EMA assigns more weight to recent values, making it useful for capturing short-term trends.

# %%
df['temperature_ema'] = df['temperature_celsius'].ewm(span=5, adjust=False).mean()
df['humidity_ema'] = df['humidity'].ewm(span=5, adjust=False).mean()

# %%
df.head()
# Out:
#                         country location_name  latitude  longitude  \
# last_updated
# 2024-05-16 12:45:00     Armenia       Yerevan     40.18      44.51
# 2024-05-16 18:45:00   Australia      Canberra    -35.28     149.22
# 2024-05-16 10:45:00     Austria        Vienna     48.20      16.37
# 2024-05-16 12:45:00  Azerbaijan          Baku     40.40      49.88
# 2024-05-16 04:45:00     Bahamas        Nassau     25.08     -77.35
#
#                              timezone  temperature_celsius condition_text  \
# last_updated
# 2024-05-16 12:45:00      Asia/Yerevan                 19.0  Partly cloudy
# 2024-05-16 18:45:00  Australia/Sydney                  9.0          Clear
# 2024-05-16 10:45:00     Europe/Vienna                 16.0  Partly cloudy
# 2024-05-16 12:45:00         Asia/Baku                 17.0  Partly cloudy
# 2024-05-16 04:45:00    America/Nassau                 27.0  Partly cloudy
#
#                      wind_kph  wind_degree wind_direction  ...  hour_of_day  \
# last_updated                                               ...
# 2024-05-16 12:45:00       6.8          140             SE  ...           12
# 2024-05-16 18:45:00       4.0          100              E  ...           18
# 2024-05-16 10:45:00      20.2          110            ESE  ...           10
# 2024-05-16 12:45:00       6.8           20            NNE  ...           12
# 2024-05-16 04:45:00      25.9          180              S  ...            4
#
#                      month_sin  month_cos      hour_sin      hour_cos  \
# last_updated
# 2024-05-16 12:45:00        0.5  -0.866025  1.224647e-16 -1.000000e+00
# 2024-05-16 18:45:00        0.5  -0.866025 -1.000000e+00 -1.836970e-16
# 2024-05-16 10:45:00        0.5  -0.866025  5.000000e-01 -8.660254e-01
# 2024-05-16 12:45:00        0.5  -0.866025  1.224647e-16 -1.000000e+00
# 2024-05-16 04:45:00        0.5  -0.866025  8.660254e-01  5.000000e-01
#
#                      humidity_temperature_interaction  wind_category  \
# last_updated
# 2024-05-16 12:45:00                             760.0            low
# 2024-05-16 18:45:00                             783.0            low
# 2024-05-16 10:45:00                            1008.0           high
# 2024-05-16 12:45:00                            1156.0            low
# 2024-05-16 04:45:00                            2403.0           high
#
#                      dew_point  temperature_ema  humidity_ema
# last_updated
# 2024-05-16 12:45:00        7.0        19.000000     40.000000
# 2024-05-16 18:45:00        6.4        15.666667     55.666667
# 2024-05-16 10:45:00        8.6        15.777778     58.111111
# 2024-05-16 12:45:00       10.6        16.185185     61.407407
# 2024-05-16 04:45:00       24.8        19.790123     70.604938
#
# [5 rows x 54 columns]

# %%
df.isna().sum().sum()
# Out:
# np.int64(2560)

# %%
df.fillna(method='bfill', inplace=True)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("../data/feature_engineered_cleaned.csv")
